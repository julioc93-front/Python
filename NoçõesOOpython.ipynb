# %%
# ETE Cícero Dias
# Python Noções OO
# Estudante: Julio Cesar
class Carro:
  def __init__(self):
    self._nrodas = 4
  def set_nrodas(self, n):
    self._nrodas = n
gol = Carro()
gol._nrodas

gol.set_nrodas(10)
gol._nrodas

#imprime o objeto
#c = Carro()
#print (nrodas)
# Out:
# 10
